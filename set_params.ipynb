# %%
dbutils.widgets.text("overwrite_staging_schema", "false", "Overwrite Schemas")
dbutils.widgets.text("lookups_database_prefix", "lookups", "Lookups Overwrite Schemas")
dbutils.widgets.text("staging_database_prefix", "staging", "Staging Overwrite Schemas")
dbutils.widgets.text("bronze_database_prefix", "bronze", "Bronze Overwrite Schemas")
dbutils.widgets.text("silver_database_prefix", "silver", "Silver Overwrite Schemas")
dbutils.widgets.text("gold_database_prefix", "gold", "Gold Overwrite Schemas")

# %%
overwrite_staging_schema = dbutils.widgets.get('overwrite_staging_schema')
lookups_database_prefix = dbutils.widgets.get('lookups_database_prefix')
staging_database_prefix = dbutils.widgets.get('staging_database_prefix')
bronze_database_prefix = dbutils.widgets.get('bronze_database_prefix')
silver_database_prefix = dbutils.widgets.get('silver_database_prefix')
gold_database_prefix = dbutils.widgets.get('gold_database_prefix')

# %%
# Set task values for downstream job tasks
dbutils.jobs.taskValues.set(key='par_overwrite_staging_schema', value=overwrite_staging_schema)
dbutils.jobs.taskValues.set(key='par_lookups_database_prefix', value=lookups_database_prefix)
dbutils.jobs.taskValues.set(key='par_staging_database_prefix', value=staging_database_prefix)
dbutils.jobs.taskValues.set(key='par_bronze_database_prefix', value=bronze_database_prefix)
dbutils.jobs.taskValues.set(key='par_silver_database_prefix', value=silver_database_prefix)
dbutils.jobs.taskValues.set(key='par_gold_database_prefix', value=gold_database_prefix)

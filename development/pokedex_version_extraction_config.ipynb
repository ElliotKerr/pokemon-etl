# %%
import yaml
import json

YAML_PATH = "./pokedex_version_extraction_config.yaml"

with open(YAML_PATH, "r") as f:
    config = yaml.safe_load(f)

tables_list = config.get("tables", [])
dbutils.jobs.taskValues.set(key="tables_payload", value=json.dumps(tables_list))

print(f"Loaded {len(tables_list)} entries from YAML config.")

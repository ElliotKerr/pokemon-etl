# %%
# %pip install roman

# %%
import requests
import time
import roman
from datetime import datetime, timezone
from pyspark.sql.functions import col, explode, lit, current_timestamp, split, udf, first, expr
from pyspark.sql.types import IntegerType, BooleanType, StructType, StructField, StringType, ArrayType

# %%
LOOKUPS_DATABASE_PREFIX = 'pokemon.lookups'
STAGING_DATABASE_PREFIX = 'pokemon.staging'
BRONZE_DATABASE_PREFIX = 'pokemon.bronze'
SILVER_DATABASE_PREFIX = 'pokemon.silver'
GOLD_DATABASE_PREFIX = 'pokemon.gold'

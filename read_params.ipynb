# %%
import json

# %%
par_overwrite_staging_schema = dbutils.jobs.taskValues.get(taskKey="Set_Task_Params", key='par_overwrite_staging_schema', debugValue='false')
par_lookups_database_prefix = dbutils.jobs.taskValues.get(taskKey="Set_Task_Params", key='par_lookups_database_prefix', debugValue='lookups')
par_staging_database_prefix = dbutils.jobs.taskValues.get(taskKey="Set_Task_Params", key='par_staging_database_prefix', debugValue='staging')
par_bronze_database_prefix = dbutils.jobs.taskValues.get(taskKey="Set_Task_Params", key='par_bronze_database_prefix', debugValue='bronze')
par_silver_database_prefix = dbutils.jobs.taskValues.get(taskKey="Set_Task_Params", key='par_silver_database_prefix', debugValue='silver')
par_gold_database_prefix = dbutils.jobs.taskValues.get(taskKey="Set_Task_Params", key='par_gold_database_prefix', debugValue='gold')

catalog_name = 'pokemon'

# %%
OVERWRITE_STAGING_SCHEMA = json.loads(par_overwrite_staging_schema.lower())
LOOKUPS_DATABASE_PREFIX = f'{catalog_name}.{par_lookups_database_prefix}'
STAGING_DATABASE_PREFIX = f'{catalog_name}.{par_staging_database_prefix}'
BRONZE_DATABASE_PREFIX = f'{catalog_name}.{par_bronze_database_prefix}'
SILVER_DATABASE_PREFIX = f'{catalog_name}.{par_silver_database_prefix}'
GOLD_DATABASE_PREFIX = f'{catalog_name}.{par_gold_database_prefix}'

# %%
print(f'OVERWRITE_STAGING_SCHEMA = {OVERWRITE_STAGING_SCHEMA}')
print(f'LOOKUPS_DATABASE_PREFIX = {LOOKUPS_DATABASE_PREFIX}')
print(f'STAGING_DATABASE_PREFIX = {STAGING_DATABASE_PREFIX}')
print(f'BRONZE_DATABASE_PREFIX = {BRONZE_DATABASE_PREFIX}')
print(f'SILVER_DATABASE_PREFIX = {SILVER_DATABASE_PREFIX}')
print(f'GOLD_DATABASE_PREFIX = {GOLD_DATABASE_PREFIX}')
